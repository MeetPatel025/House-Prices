# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error as MSE
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder

from sklearn.model_selection import GridSearchCV

# %%
df_train = pd.read_csv("train.csv")
df_train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...          ...       ...  ...      ...    ...    ...         ...     ...
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0         2   2008        WD         Normal     208500
# 1         5   2007        WD         Normal     181500
# 2         9   2008        WD         Normal     223500
# 3         2   2006        WD        Abnorml     140000
# 4        12   2008        WD         Normal     250000
# ...     ...    ...       ...            ...        ...
# 1455      8   2007        WD         Normal     175000
# 1456      2   2010        WD         Normal     210000
# 1457      5   2010        WD         Normal     266500
# 1458      4   2010        WD         Normal     142125
# 1459      6   2008        WD         Normal     147500
#
# [1460 rows x 81 columns]

# %%
df_train.shape
# Out:
# (1460, 81)

# %%
df_test = pd.read_csv("test.csv")
df_test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# 0       0      6    2010        WD         Normal
# 1   12500      6    2010        WD         Normal
# 2       0      3    2010        WD         Normal
# 3       0      6    2010        WD         Normal
# 4       0      1    2010        WD         Normal
#
# [5 rows x 80 columns]

# %%
sample_submission = pd.read_csv("sample_submission.csv")
sample_submission.head()
# Out:
#      Id      SalePrice
# 0  1461  169277.052498
# 1  1462  187758.393989
# 2  1463  183583.683570
# 3  1464  179317.477511
# 4  1465  150730.079977

# %%
# Pre-Process the data

# response variable
target_column = 'SalePrice'

# Extract features and target variable from the training set
X = df_train.drop(target_column, axis=1)
y = df_train[target_column]

# Identify categorical columns in the dataset
categorical_cols = X.select_dtypes(include=['object']).columns

# Identify quantative columns in the dataset
numerical_cols = X.select_dtypes(exclude=['object']).columns

# Split the data into training and testing sets- 80% is train, and 20% is test data.
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# Create transformers for numerical and categorical columns
numerical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler())
])

categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

# Create a preprocessor to apply transformers to appropriate columns
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_cols),
        ('cat', categorical_transformer, categorical_cols)
    ])

# %%
# Model 1: Random Forest

# %%
# Define the parameter grid
param_grid = {
    'regressor__n_estimators': [1, 5, 10, 25, 50],
    'regressor__max_depth': [None, 2, 5, 7, 10],
    'regressor__min_samples_split': [2, 4, 5, 7, 10],
    'regressor__min_samples_leaf': [1, 2, 3, 5, 8]
}

# Create a Random Forest regressor model
rf_model = RandomForestRegressor(random_state=12)

# Create a pipeline with the preprocessor and Random Forest model
model = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('regressor', rf_model)
])

# Instantiate GridSearchCV with the pipeline and parameter grid
grid_search = GridSearchCV(model,  # Use the entire pipeline here
                           param_grid=param_grid, 
                           cv=5, 
                           scoring='neg_mean_squared_error', 
                           n_jobs=-1)

# Fit the grid search to the data
grid_search.fit(X_train, y_train)

# Print the best parameters and best score found
print("Best Parameters:", grid_search.best_params_)
print("Best Score:", -grid_search.best_score_)  # Take the negative of the score to get MSE
# Out:
# Best Parameters: {'regressor__max_depth': 10, 'regressor__min_samples_leaf': 1, 'regressor__min_samples_split': 5, 'regressor__n_estimators': 50}
# Best Score: 947324240.4021267

# %%
# best model found using cross validation 

# Get the best model from the grid search
best_model_RF = grid_search.best_estimator_

# Make predictions on the test set using the best model
y_test_pred = best_model_RF.predict(X_test)

# %%
# Calculate RMSE using cross-validation on the training data
cv_scores = cross_val_score(model, X_train, y_train, cv=5, scoring='neg_mean_squared_error')
cv_rmse = np.sqrt(-np.mean(cv_scores))

print("RMSE using cross-validation on training data:", cv_rmse)


# Make predictions on the training set
y_train_pred = best_model_RF.predict(X_train)

# Calculate RMSE on the entire training set
train_rmse = np.sqrt(MSE(y_train, y_train_pred))

print("\nRMSE on the entire training set:", train_rmse)
# Out:
# RMSE using cross-validation on training data: 31432.26977869758
#
# RMSE on the entire training set: 14362.519147713425

# %%
# get the RMSE value for rf model

# Calculate Mean Squared Error
mse = MSE(y_test, y_test_pred)

# Calculate Root Mean Squared Error
rmse = np.sqrt(mse)

print(f'Root Mean Squared Error (RMSE): ${rmse:.2f}')

# the final model RF model works pretty good, because the RMSE is quite lower than CV's RMSE.
# Out:
# Root Mean Squared Error (RMSE): $27741.83

# %%
RF_pred = best_model_RF.predict(df_test)
RF_pred
# Out:
# array([128098.36563428, 150363.61747741, 179816.99766474, ...,
#        157478.50680178, 121819.25827079, 232393.82349212])

# %%
# Create a DataFrame with 'id' column from df_test and predictions column
RF_submission = pd.DataFrame({
    'id': df_test['Id'],  # Replace 'id' with the actual column name from df_test
    'SalePrice': RF_pred
})

# Display the resulting DataFrame
(RF_submission)
# Out:
#         id      SalePrice
# 0     1461  128098.365634
# 1     1462  150363.617477
# 2     1463  179816.997665
# 3     1464  183588.626790
# 4     1465  205110.974105
# ...    ...            ...
# 1454  2915   83545.998017
# 1455  2916   84723.737500
# 1456  2917  157478.506802
# 1457  2918  121819.258271
# 1458  2919  232393.823492
#
# [1459 rows x 2 columns]

# %%
# Save the DataFrame to a CSV file
RF_submission.to_csv('RF_submission.csv', index=False, header=['Id', 'SalePrice'])

# Display a message indicating the file has been saved
print("Submission file saved as 'RF_submission.csv'")
# Out:
# Submission file saved as 'RF_submission.csv'

# %%
# Model 2- Elastic Reg

# %%
import pandas as pd
import warnings
from sklearn.linear_model import ElasticNet
from sklearn.model_selection import train_test_split, cross_val_predict
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np
from sklearn.pipeline import make_pipeline

# %%
#Elastic Reg

# Create an Elastic Net regression model
elastic_net_model = ElasticNet(alpha=1.0, l1_ratio=0.5, random_state=2)

# Train the model on the training set
model.fit(X_train, y_train)

# Make predictions on the training set
y_train_pred = model.predict(X_train)

# Make predictions on the test set
y_test_pred = model.predict(X_test)

# Evaluate performance on training set
mse_train = mean_squared_error(y_train, y_train_pred)
rmse_train = np.sqrt(mse_train)
r2_train = r2_score(y_train, y_train_pred)

# Evaluate performance on test set
mse_test = mean_squared_error(y_test, y_test_pred)
rmse_test = np.sqrt(mse_test)
r2_test = r2_score(y_test, y_test_pred)

# Reset warnings to default
warnings.resetwarnings()

print(f"Training Set Metrics:")
print(f"  RMSE: {rmse_train}")
print(f"  R-squared: {r2_train}")

print(f"\nTest Set Metrics:")
print(f"  RMSE: {rmse_test}")
print(f"  R-squared: {r2_test}")
# Out:
# Training Set Metrics:
#   RMSE: 32735.148091387862
#   R-squared: 0.8241050725740836
#
# Test Set Metrics:
#   RMSE: 35081.51772294235
#   R-squared: 0.827436531563604

# %%
model_elastic = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('regressor', elastic_net_model)
])

# model_elastic.get_params()

# %%
# using CV

import warnings
from sklearn.exceptions import ConvergenceWarning

# Suppress warnings from the ElasticNet model
with warnings.catch_warnings():
    warnings.filterwarnings('ignore', category=ConvergenceWarning)


# Create an Elastic Net regression model
elastic_net_model = ElasticNet()

# Create a pipeline with the preprocessor and Elastic Net model
model_elastic = make_pipeline(preprocessor, elastic_net_model)

# Define the parameter grid
param_grid = {
    'elasticnet__alpha': [0.01, 0.1, 1.0, 10.0],
    'elasticnet__l1_ratio': [0.1, 0.5, 0.7, 0.9, 0.95, 0.99, 1.0],
    'elasticnet__max_iter': [1000, 2000, 5000]
}

# Instantiate GridSearchCV with the pipeline and parameter grid
elastic_grid_search = GridSearchCV(estimator=model_elastic, 
                                   param_grid=param_grid, 
                                   cv=5, 
                                   scoring='neg_mean_squared_error', 
                                   n_jobs=-1,
                                   verbose=2)

# Fit the grid search to the data
elastic_grid_search.fit(X_train, y_train)

# Print the best parameters and best score found
#print("Best Parameters:", elastic_grid_search.best_params_)
#print("Best Score:", -elastic_grid_search.best_score_)  # Take the negative of the score to get MSE

# Optionally, you can evaluate the model on the test set
y_test_pred = elastic_grid_search.best_estimator_.predict(X_test)
mse_test = mean_squared_error(y_test, y_test_pred)
print(f'Mean Squared Error (Test Set): {mse_test}')

# Reset warnings to default if needed
warnings.resetwarnings()
# Out:
# Fitting 5 folds for each of 84 candidates, totalling 420 fits
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4374707790.763245, tolerance: 564401606.4495292
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 248530071546.19028, tolerance: 592040298.8822355
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 206960094492.7416, tolerance: 564401606.4495292
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 207966873535.1886, tolerance: 546077078.4629872
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 211050147286.04276, tolerance: 553361597.3105724
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 274115525105.24692, tolerance: 590182589.1082145
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 203850907583.70276, tolerance: 564401606.4495292
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 253112109700.68936, tolerance: 592040298.8822355
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 202599222674.27014, tolerance: 546077078.4629872
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 235221538909.7426, tolerance: 553361597.3105724
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 276815222388.6053, tolerance: 590182589.1082145
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 193211030608.77945, tolerance: 564401606.4495292
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 238275050403.39392, tolerance: 592040298.8822355
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 193454220833.47488, tolerance: 546077078.4629872
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 215806066713.04974, tolerance: 553361597.3105724
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 262088594438.95056, tolerance: 590182589.1082145
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 186933547490.34186, tolerance: 564401606.4495292
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 233826147782.1554, tolerance: 592040298.8822355
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 185738518048.50455, tolerance: 546077078.4629872
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 219287712059.8766, tolerance: 553361597.3105724
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 256732017922.98935, tolerance: 590182589.1082145
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 185064227416.65143, tolerance: 564401606.4495292
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 231125547854.39056, tolerance: 592040298.8822355
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 184068616831.16342, tolerance: 546077078.4629872
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 215843640961.4403, tolerance: 553361597.3105724
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 254039807750.84702, tolerance: 590182589.1082145
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 160866741857.72205, tolerance: 564401606.4495292
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 197478901689.52335, tolerance: 592040298.8822355
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 153623715186.3153, tolerance: 546077078.4629872
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 187316404535.28162, tolerance: 553361597.3105724
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 218416486605.94724, tolerance: 590182589.1082145
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 160437290493.35248, tolerance: 564401606.4495292
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 124443225306.92252, tolerance: 564401606.4495292
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 196831285329.11877, tolerance: 592040298.8822355
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 153225695061.8405, tolerance: 546077078.4629872
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 142297075716.6128, tolerance: 592040298.8822355
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 130271930751.91649, tolerance: 546077078.4629872
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 100213431634.6287, tolerance: 553361597.3105724
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 166130842780.15762, tolerance: 590182589.1082145
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 186526080839.61057, tolerance: 553361597.3105724
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 217762215222.75995, tolerance: 590182589.1082145
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 59603266039.53804, tolerance: 564401606.4495292
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 104986704902.02498, tolerance: 592040298.8822355
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 55319044779.05693, tolerance: 546077078.4629872
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 88898052919.2572, tolerance: 553361597.3105724
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 83225122657.13815, tolerance: 590182589.1082145
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 158449869444.7245, tolerance: 564401606.4495292
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 60640204802.82385, tolerance: 592040298.8822355
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 59535562566.61377, tolerance: 564401606.4495292
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 193848994995.32126, tolerance: 592040298.8822355
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 47295566593.405975, tolerance: 546077078.4629872
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 182905658572.8527, tolerance: 553361597.3105724
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 151431528244.13095, tolerance: 546077078.4629872
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 214825816565.5659, tolerance: 590182589.1082145
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 53792759541.0629, tolerance: 553361597.3105724
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 83188137241.60522, tolerance: 590182589.1082145
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 44702340545.989105, tolerance: 592040298.8822355
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 50868477829.98694, tolerance: 564401606.4495292
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 46205111812.76434, tolerance: 546077078.4629872
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 47969471020.755035, tolerance: 553361597.3105724
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 50025088269.833374, tolerance: 590182589.1082145
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 187462281044.72842, tolerance: 564401606.4495292
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 230265602989.19855, tolerance: 592040298.8822355
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 188567720266.98462, tolerance: 546077078.4629872
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 205143635284.70282, tolerance: 553361597.3105724
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 254118316555.18454, tolerance: 590182589.1082145
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 56364290923.07379, tolerance: 564401606.4495292
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 48268089517.444885, tolerance: 592040298.8822355
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 76277942145.42764, tolerance: 546077078.4629872
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3724170070.111267, tolerance: 553361597.3105724
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 72693393449.42978, tolerance: 590182589.1082145
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 51077248982.76163, tolerance: 564401606.4495292
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 34936788096.40216, tolerance: 592040298.8822355
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 40407013335.59888, tolerance: 546077078.4629872
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 48082384555.43234, tolerance: 553361597.3105724
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 65713208059.65167, tolerance: 590182589.1082145
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 34883710629.59906, tolerance: 592040298.8822355
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 49297230857.91278, tolerance: 564401606.4495292
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 29619994477.592712, tolerance: 546077078.4629872
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 56749345442.553406, tolerance: 553361597.3105724
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 65712499006.91748, tolerance: 590182589.1082145
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 49283319010.4294, tolerance: 564401606.4495292
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12525279562.141449, tolerance: 592040298.8822355
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8379967089.949829, tolerance: 590182589.1082145
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 56746572029.40491, tolerance: 553361597.3105724
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9315642563.532318, tolerance: 546077078.4629872
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13371337599.20697, tolerance: 592040298.8822355
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8941045244.93573, tolerance: 590182589.1082145
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/meetpatel/opt/anaconda3/envs/ML/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:639: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4389490967.149536, tolerance: 553361597.3105724
#   model = cd_fast.sparse_enet_coordinate_descent(
# Mean Squared Error (Test Set): 1024286388.6872337

# %%
# best estimators using the CV method

elastic_grid_search.best_params_
# Out:
# {'elasticnet__alpha': 1.0,
#  'elasticnet__l1_ratio': 0.99,
#  'elasticnet__max_iter': 1000}
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.1, elasticnet__max_iter=1000; total time=   0.5s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.1, elasticnet__max_iter=2000; total time=   0.5s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.5, elasticnet__max_iter=1000; total time=   0.7s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.5, elasticnet__max_iter=5000; total time=   0.8s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.7, elasticnet__max_iter=2000; total time=   1.3s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.9, elasticnet__max_iter=1000; total time=   0.8s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.9, elasticnet__max_iter=2000; total time=   1.5s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.9, elasticnet__max_iter=5000; total time=   3.0s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.95, elasticnet__max_iter=5000; total time=   4.0s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.99, elasticnet__max_iter=5000; total time=   4.0s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=1.0, elasticnet__max_iter=5000; total time=   4.1s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.9, elasticnet__max_iter=5000; total time=   0.3s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.95, elasticnet__max_iter=2000; total time=   0.7s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.99, elasticnet__max_iter=1000; total time=   0.9s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.99, elasticnet__max_iter=2000; total time=   1.6s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=1.0, elasticnet__max_iter=1000; total time=   0.8s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=1.0, elasticnet__max_iter=2000; total time=   1.5s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=1.0, elasticnet__max_iter=5000; total time=   3.8s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=1.0, elasticnet__max_iter=2000; total time=   1.0s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=1.0, elasticnet__max_iter=5000; total time=   0.9s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.7, elasticnet__max_iter=1000; total time=   0.1s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.7, elasticnet__max_iter=2000; total time=   0.0s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.7, elasticnet__max_iter=5000; total time=   0.0s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.9, elasticnet__max_iter=1000; total time=   0.1s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.9, elasticnet__max_iter=2000; total time=   0.1s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.95, elasticnet__max_iter=1000; total time=   0.1s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.95, elasticnet__max_iter=1000; total time=   0.1s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.99, elasticnet__max_iter=1000; total time=   0.1s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.99, elasticnet__max_iter=2000; total time=   0.2s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=1.0, elasticnet__max_iter=2000; total time=   0.3s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.1, elasticnet__max_iter=1000; total time=   0.6s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.1, elasticnet__max_iter=5000; total time=   0.5s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.5, elasticnet__max_iter=1000; total time=   0.7s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.5, elasticnet__max_iter=2000; total time=   0.8s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.7, elasticnet__max_iter=1000; total time=   0.8s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.7, elasticnet__max_iter=5000; total time=   1.1s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.9, elasticnet__max_iter=1000; total time=   0.8s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.9, elasticnet__max_iter=5000; total time=   2.7s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.95, elasticnet__max_iter=2000; total time=   1.6s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.99, elasticnet__max_iter=1000; total time=   0.8s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.99, elasticnet__max_iter=1000; total time=   0.8s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.99, elasticnet__max_iter=2000; total time=   1.6s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.99, elasticnet__max_iter=5000; total time=   4.2s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=1.0, elasticnet__max_iter=5000; total time=   3.8s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.9, elasticnet__max_iter=1000; total time=   0.3s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.9, elasticnet__max_iter=2000; total time=   0.3s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.95, elasticnet__max_iter=1000; total time=   0.5s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.95, elasticnet__max_iter=2000; total time=   0.5s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.99, elasticnet__max_iter=1000; total time=   0.8s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.99, elasticnet__max_iter=5000; total time=   1.7s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=1.0, elasticnet__max_iter=1000; total time=   0.8s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=1.0, elasticnet__max_iter=2000; total time=   1.5s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.1, elasticnet__max_iter=1000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.1, elasticnet__max_iter=2000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.1, elasticnet__max_iter=5000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.1, elasticnet__max_iter=5000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.5, elasticnet__max_iter=1000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.5, elasticnet__max_iter=1000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.5, elasticnet__max_iter=2000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.5, elasticnet__max_iter=2000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.5, elasticnet__max_iter=5000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.5, elasticnet__max_iter=5000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.7, elasticnet__max_iter=1000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.7, elasticnet__max_iter=2000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.7, elasticnet__max_iter=2000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.7, elasticnet__max_iter=5000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.9, elasticnet__max_iter=1000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.9, elasticnet__max_iter=1000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.9, elasticnet__max_iter=2000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.9, elasticnet__max_iter=5000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.9, elasticnet__max_iter=5000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.95, elasticnet__max_iter=1000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.95, elasticnet__max_iter=1000; total time=   0.2s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.95, elasticnet__max_iter=2000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.95, elasticnet__max_iter=5000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.95, elasticnet__max_iter=5000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.99, elasticnet__max_iter=1000; total time=   0.2s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.99, elasticnet__max_iter=2000; total time=   0.3s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.99, elasticnet__max_iter=5000; total time=   0.3s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=1.0, elasticnet__max_iter=2000; total time=   1.1s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.1, elasticnet__max_iter=1000; total time=   0.0s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.1, elasticnet__max_iter=1000; total time=   0.1s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.1, elasticnet__max_iter=1000; total time=   0.0s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.1, elasticnet__max_iter=1000; total time=   0.0s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.1, elasticnet__max_iter=1000; total time=   0.0s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.1, elasticnet__max_iter=2000; total time=   0.0s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.1, elasticnet__max_iter=2000; total time=   0.1s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.1, elasticnet__max_iter=2000; total time=   0.0s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.1, elasticnet__max_iter=2000; total time=   0.0s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.1, elasticnet__max_iter=5000; total time=   0.0s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.1, elasticnet__max_iter=5000; total time=   0.1s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.5, elasticnet__max_iter=1000; total time=   0.1s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.5, elasticnet__max_iter=2000; total time=   0.1s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.5, elasticnet__max_iter=5000; total time=   0.1s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.7, elasticnet__max_iter=1000; total time=   0.1s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.7, elasticnet__max_iter=5000; total time=   0.0s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.9, elasticnet__max_iter=1000; total time=   0.1s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.9, elasticnet__max_iter=2000; total time=   0.1s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.95, elasticnet__max_iter=1000; total time=   0.1s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.95, elasticnet__max_iter=5000; total time=   0.1s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.95, elasticnet__max_iter=5000; total time=   0.1s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.99, elasticnet__max_iter=5000; total time=   0.1s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.99, elasticnet__max_iter=5000; total time=   0.1s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=1.0, elasticnet__max_iter=2000; total time=   0.2s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=1.0, elasticnet__max_iter=5000; total time=   0.2s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.1, elasticnet__max_iter=1000; total time=   0.6s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.1, elasticnet__max_iter=2000; total time=   0.5s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.5, elasticnet__max_iter=1000; total time=   0.8s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.5, elasticnet__max_iter=5000; total time=   0.7s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.7, elasticnet__max_iter=1000; total time=   0.8s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.7, elasticnet__max_iter=5000; total time=   1.3s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.9, elasticnet__max_iter=2000; total time=   1.6s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.9, elasticnet__max_iter=5000; total time=   3.3s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.95, elasticnet__max_iter=5000; total time=   4.0s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=1.0, elasticnet__max_iter=1000; total time=   0.8s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=1.0, elasticnet__max_iter=1000; total time=   0.8s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=1.0, elasticnet__max_iter=2000; total time=   1.5s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=1.0, elasticnet__max_iter=2000; total time=   1.6s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.1, elasticnet__max_iter=2000; total time=   0.2s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.1, elasticnet__max_iter=2000; total time=   0.2s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.1, elasticnet__max_iter=5000; total time=   0.2s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.5, elasticnet__max_iter=1000; total time=   0.2s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.5, elasticnet__max_iter=1000; total time=   0.2s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.5, elasticnet__max_iter=2000; total time=   0.1s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.5, elasticnet__max_iter=2000; total time=   0.2s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.5, elasticnet__max_iter=5000; total time=   0.2s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.5, elasticnet__max_iter=5000; total time=   0.2s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.7, elasticnet__max_iter=1000; total time=   0.2s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.7, elasticnet__max_iter=2000; total time=   0.2s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.7, elasticnet__max_iter=2000; total time=   0.2s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.7, elasticnet__max_iter=5000; total time=   0.2s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.7, elasticnet__max_iter=5000; total time=   0.2s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.9, elasticnet__max_iter=1000; total time=   0.4s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.9, elasticnet__max_iter=5000; total time=   0.3s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.95, elasticnet__max_iter=1000; total time=   0.5s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.95, elasticnet__max_iter=5000; total time=   0.6s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.99, elasticnet__max_iter=2000; total time=   1.6s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.99, elasticnet__max_iter=5000; total time=   2.2s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=1.0, elasticnet__max_iter=5000; total time=   3.9s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.99, elasticnet__max_iter=5000; total time=   0.3s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=1.0, elasticnet__max_iter=1000; total time=   0.8s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=1.0, elasticnet__max_iter=2000; total time=   1.5s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.7, elasticnet__max_iter=2000; total time=   0.0s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.9, elasticnet__max_iter=1000; total time=   0.1s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.9, elasticnet__max_iter=2000; total time=   0.0s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.9, elasticnet__max_iter=5000; total time=   0.1s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.95, elasticnet__max_iter=2000; total time=   0.1s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.95, elasticnet__max_iter=5000; total time=   0.1s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.99, elasticnet__max_iter=2000; total time=   0.1s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.99, elasticnet__max_iter=2000; total time=   0.1s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=1.0, elasticnet__max_iter=2000; total time=   0.2s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=1.0, elasticnet__max_iter=5000; total time=   0.2s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.1, elasticnet__max_iter=1000; total time=   0.6s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.1, elasticnet__max_iter=5000; total time=   0.5s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.5, elasticnet__max_iter=2000; total time=   0.9s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.7, elasticnet__max_iter=1000; total time=   0.8s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.7, elasticnet__max_iter=2000; total time=   1.0s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.7, elasticnet__max_iter=5000; total time=   1.2s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.9, elasticnet__max_iter=5000; total time=   3.5s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.95, elasticnet__max_iter=5000; total time=   4.1s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.99, elasticnet__max_iter=2000; total time=   1.6s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=1.0, elasticnet__max_iter=1000; total time=   0.8s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=1.0, elasticnet__max_iter=2000; total time=   1.6s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=1.0, elasticnet__max_iter=2000; total time=   1.6s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.1, elasticnet__max_iter=2000; total time=   0.2s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.1, elasticnet__max_iter=2000; total time=   0.2s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.1, elasticnet__max_iter=5000; total time=   0.1s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.1, elasticnet__max_iter=5000; total time=   0.2s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.5, elasticnet__max_iter=1000; total time=   0.2s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.5, elasticnet__max_iter=2000; total time=   0.2s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.5, elasticnet__max_iter=2000; total time=   0.2s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.5, elasticnet__max_iter=5000; total time=   0.2s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.7, elasticnet__max_iter=1000; total time=   0.2s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.7, elasticnet__max_iter=1000; total time=   0.2s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.7, elasticnet__max_iter=2000; total time=   0.2s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.7, elasticnet__max_iter=2000; total time=   0.2s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.7, elasticnet__max_iter=5000; total time=   0.2s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.9, elasticnet__max_iter=1000; total time=   0.4s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.9, elasticnet__max_iter=5000; total time=   0.4s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.95, elasticnet__max_iter=1000; total time=   0.5s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.95, elasticnet__max_iter=5000; total time=   0.5s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.99, elasticnet__max_iter=1000; total time=   0.8s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.99, elasticnet__max_iter=5000; total time=   1.8s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=1.0, elasticnet__max_iter=2000; total time=   1.5s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=1.0, elasticnet__max_iter=5000; total time=   3.9s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=1.0, elasticnet__max_iter=1000; total time=   0.9s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=1.0, elasticnet__max_iter=5000; total time=   0.9s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.1, elasticnet__max_iter=5000; total time=   0.0s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.5, elasticnet__max_iter=1000; total time=   0.1s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.5, elasticnet__max_iter=1000; total time=   0.0s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.5, elasticnet__max_iter=2000; total time=   0.0s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.5, elasticnet__max_iter=5000; total time=   0.1s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.7, elasticnet__max_iter=2000; total time=   0.1s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.7, elasticnet__max_iter=5000; total time=   0.1s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.9, elasticnet__max_iter=5000; total time=   0.1s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.95, elasticnet__max_iter=5000; total time=   0.1s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.95, elasticnet__max_iter=5000; total time=   0.1s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.99, elasticnet__max_iter=5000; total time=   0.1s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=1.0, elasticnet__max_iter=1000; total time=   0.2s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=1.0, elasticnet__max_iter=5000; total time=   0.2s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.1, elasticnet__max_iter=1000; total time=   0.6s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.1, elasticnet__max_iter=5000; total time=   0.6s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.5, elasticnet__max_iter=2000; total time=   0.8s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.5, elasticnet__max_iter=5000; total time=   0.6s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.7, elasticnet__max_iter=1000; total time=   0.8s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.7, elasticnet__max_iter=5000; total time=   1.1s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.9, elasticnet__max_iter=1000; total time=   0.8s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.9, elasticnet__max_iter=5000; total time=   2.8s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.95, elasticnet__max_iter=2000; total time=   1.5s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.99, elasticnet__max_iter=1000; total time=   0.8s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.99, elasticnet__max_iter=2000; total time=   1.7s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.99, elasticnet__max_iter=2000; total time=   1.6s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=1.0, elasticnet__max_iter=1000; total time=   0.8s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=1.0, elasticnet__max_iter=1000; total time=   0.8s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=1.0, elasticnet__max_iter=2000; total time=   1.6s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=1.0, elasticnet__max_iter=5000; total time=   4.0s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.9, elasticnet__max_iter=2000; total time=   0.4s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.9, elasticnet__max_iter=5000; total time=   0.4s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.95, elasticnet__max_iter=2000; total time=   0.5s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.95, elasticnet__max_iter=5000; total time=   0.4s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.99, elasticnet__max_iter=2000; total time=   1.6s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.99, elasticnet__max_iter=5000; total time=   2.0s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=1.0, elasticnet__max_iter=5000; total time=   3.8s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.99, elasticnet__max_iter=1000; total time=   0.3s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.99, elasticnet__max_iter=2000; total time=   0.2s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.99, elasticnet__max_iter=5000; total time=   0.3s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=1.0, elasticnet__max_iter=2000; total time=   1.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=1.0, elasticnet__max_iter=5000; total time=   0.8s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.5, elasticnet__max_iter=2000; total time=   0.1s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.5, elasticnet__max_iter=5000; total time=   0.0s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.7, elasticnet__max_iter=1000; total time=   0.0s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.7, elasticnet__max_iter=2000; total time=   0.1s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.9, elasticnet__max_iter=1000; total time=   0.1s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.9, elasticnet__max_iter=2000; total time=   0.1s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.9, elasticnet__max_iter=5000; total time=   0.1s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.95, elasticnet__max_iter=2000; total time=   0.1s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.95, elasticnet__max_iter=2000; total time=   0.1s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.99, elasticnet__max_iter=2000; total time=   0.1s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.99, elasticnet__max_iter=2000; total time=   0.1s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=1.0, elasticnet__max_iter=2000; total time=   0.4s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.1, elasticnet__max_iter=2000; total time=   0.6s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.1, elasticnet__max_iter=5000; total time=   0.5s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.5, elasticnet__max_iter=1000; total time=   0.8s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.5, elasticnet__max_iter=5000; total time=   0.7s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.7, elasticnet__max_iter=2000; total time=   1.0s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.7, elasticnet__max_iter=5000; total time=   1.1s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.9, elasticnet__max_iter=2000; total time=   1.5s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.95, elasticnet__max_iter=1000; total time=   0.8s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.95, elasticnet__max_iter=1000; total time=   0.8s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.95, elasticnet__max_iter=2000; total time=   1.6s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.99, elasticnet__max_iter=1000; total time=   0.7s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.99, elasticnet__max_iter=1000; total time=   0.8s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.99, elasticnet__max_iter=2000; total time=   1.7s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.99, elasticnet__max_iter=5000; total time=   3.9s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=1.0, elasticnet__max_iter=5000; total time=   4.0s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.9, elasticnet__max_iter=1000; total time=   0.4s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.9, elasticnet__max_iter=2000; total time=   0.4s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.95, elasticnet__max_iter=1000; total time=   0.5s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.95, elasticnet__max_iter=2000; total time=   0.5s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.99, elasticnet__max_iter=1000; total time=   0.8s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.99, elasticnet__max_iter=2000; total time=   1.6s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=1.0, elasticnet__max_iter=1000; total time=   0.8s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=1.0, elasticnet__max_iter=2000; total time=   1.5s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.1, elasticnet__max_iter=1000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.1, elasticnet__max_iter=1000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.1, elasticnet__max_iter=1000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.1, elasticnet__max_iter=1000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.1, elasticnet__max_iter=2000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.1, elasticnet__max_iter=2000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.1, elasticnet__max_iter=5000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.5, elasticnet__max_iter=1000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.5, elasticnet__max_iter=1000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.5, elasticnet__max_iter=2000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.5, elasticnet__max_iter=5000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.7, elasticnet__max_iter=1000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.7, elasticnet__max_iter=1000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.7, elasticnet__max_iter=2000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.7, elasticnet__max_iter=5000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.7, elasticnet__max_iter=5000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.7, elasticnet__max_iter=5000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.9, elasticnet__max_iter=1000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.9, elasticnet__max_iter=2000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.9, elasticnet__max_iter=2000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.9, elasticnet__max_iter=5000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.9, elasticnet__max_iter=5000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.95, elasticnet__max_iter=1000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.95, elasticnet__max_iter=2000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.95, elasticnet__max_iter=2000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.95, elasticnet__max_iter=5000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.99, elasticnet__max_iter=1000; total time=   0.3s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.99, elasticnet__max_iter=2000; total time=   0.3s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=1.0, elasticnet__max_iter=1000; total time=   0.8s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=1.0, elasticnet__max_iter=2000; total time=   1.1s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.1, elasticnet__max_iter=2000; total time=   0.1s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.1, elasticnet__max_iter=5000; total time=   0.0s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.1, elasticnet__max_iter=5000; total time=   0.0s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.5, elasticnet__max_iter=1000; total time=   0.1s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.5, elasticnet__max_iter=1000; total time=   0.0s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.5, elasticnet__max_iter=2000; total time=   0.1s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.5, elasticnet__max_iter=5000; total time=   0.1s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.7, elasticnet__max_iter=1000; total time=   0.1s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.7, elasticnet__max_iter=5000; total time=   0.0s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.9, elasticnet__max_iter=1000; total time=   0.0s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.9, elasticnet__max_iter=5000; total time=   0.1s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.95, elasticnet__max_iter=1000; total time=   0.1s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.95, elasticnet__max_iter=1000; total time=   0.1s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.99, elasticnet__max_iter=1000; total time=   0.1s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.99, elasticnet__max_iter=1000; total time=   0.1s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=1.0, elasticnet__max_iter=1000; total time=   0.2s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=1.0, elasticnet__max_iter=2000; total time=   0.2s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=1.0, elasticnet__max_iter=5000; total time=   0.2s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.1, elasticnet__max_iter=2000; total time=   0.6s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.1, elasticnet__max_iter=5000; total time=   0.6s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.5, elasticnet__max_iter=2000; total time=   0.8s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.5, elasticnet__max_iter=5000; total time=   0.8s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.7, elasticnet__max_iter=2000; total time=   1.1s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.9, elasticnet__max_iter=1000; total time=   0.9s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.9, elasticnet__max_iter=2000; total time=   1.5s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.95, elasticnet__max_iter=1000; total time=   0.9s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.95, elasticnet__max_iter=1000; total time=   0.8s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.95, elasticnet__max_iter=2000; total time=   1.6s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.95, elasticnet__max_iter=5000; total time=   3.9s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.99, elasticnet__max_iter=5000; total time=   4.0s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.1, elasticnet__max_iter=1000; total time=   0.1s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.1, elasticnet__max_iter=1000; total time=   0.2s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.1, elasticnet__max_iter=1000; total time=   0.2s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.1, elasticnet__max_iter=1000; total time=   0.2s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.1, elasticnet__max_iter=1000; total time=   0.2s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.1, elasticnet__max_iter=2000; total time=   0.2s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.1, elasticnet__max_iter=5000; total time=   0.1s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.1, elasticnet__max_iter=5000; total time=   0.2s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.5, elasticnet__max_iter=1000; total time=   0.1s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.5, elasticnet__max_iter=1000; total time=   0.2s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.5, elasticnet__max_iter=2000; total time=   0.2s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.5, elasticnet__max_iter=5000; total time=   0.2s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.5, elasticnet__max_iter=5000; total time=   0.2s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.7, elasticnet__max_iter=1000; total time=   0.2s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.7, elasticnet__max_iter=1000; total time=   0.2s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.7, elasticnet__max_iter=2000; total time=   0.2s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.7, elasticnet__max_iter=5000; total time=   0.1s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.7, elasticnet__max_iter=5000; total time=   0.2s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.9, elasticnet__max_iter=1000; total time=   0.3s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.9, elasticnet__max_iter=2000; total time=   0.3s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.95, elasticnet__max_iter=1000; total time=   0.6s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.95, elasticnet__max_iter=5000; total time=   0.5s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.99, elasticnet__max_iter=1000; total time=   0.8s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.99, elasticnet__max_iter=5000; total time=   2.6s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=1.0, elasticnet__max_iter=2000; total time=   1.6s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.1, elasticnet__max_iter=2000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.1, elasticnet__max_iter=2000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.1, elasticnet__max_iter=5000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.1, elasticnet__max_iter=5000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.5, elasticnet__max_iter=1000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.5, elasticnet__max_iter=2000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.5, elasticnet__max_iter=2000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.5, elasticnet__max_iter=5000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.5, elasticnet__max_iter=5000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.7, elasticnet__max_iter=1000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.7, elasticnet__max_iter=1000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.7, elasticnet__max_iter=2000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.7, elasticnet__max_iter=2000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.7, elasticnet__max_iter=5000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.9, elasticnet__max_iter=1000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.9, elasticnet__max_iter=1000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.9, elasticnet__max_iter=2000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.9, elasticnet__max_iter=2000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.9, elasticnet__max_iter=5000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.95, elasticnet__max_iter=1000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.95, elasticnet__max_iter=1000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.95, elasticnet__max_iter=2000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.95, elasticnet__max_iter=2000; total time=   0.2s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.95, elasticnet__max_iter=5000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.99, elasticnet__max_iter=1000; total time=   0.2s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.99, elasticnet__max_iter=2000; total time=   0.2s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.99, elasticnet__max_iter=5000; total time=   0.2s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=1.0, elasticnet__max_iter=1000; total time=   1.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=1.0, elasticnet__max_iter=5000; total time=   1.3s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.99, elasticnet__max_iter=1000; total time=   0.1s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.99, elasticnet__max_iter=1000; total time=   0.1s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=1.0, elasticnet__max_iter=1000; total time=   0.5s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=1.0, elasticnet__max_iter=1000; total time=   0.1s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.1, elasticnet__max_iter=2000; total time=   0.7s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.5, elasticnet__max_iter=1000; total time=   0.8s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.5, elasticnet__max_iter=2000; total time=   0.7s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.7, elasticnet__max_iter=1000; total time=   0.8s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.7, elasticnet__max_iter=2000; total time=   1.2s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.9, elasticnet__max_iter=1000; total time=   0.8s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.9, elasticnet__max_iter=2000; total time=   1.5s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.95, elasticnet__max_iter=1000; total time=   0.8s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.95, elasticnet__max_iter=2000; total time=   1.6s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.95, elasticnet__max_iter=5000; total time=   4.1s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.99, elasticnet__max_iter=5000; total time=   3.9s
# [CV] END elasticnet__alpha=0.01, elasticnet__l1_ratio=1.0, elasticnet__max_iter=5000; total time=   4.0s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.9, elasticnet__max_iter=2000; total time=   0.3s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.9, elasticnet__max_iter=5000; total time=   0.3s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.95, elasticnet__max_iter=2000; total time=   0.5s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.95, elasticnet__max_iter=5000; total time=   0.6s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.99, elasticnet__max_iter=2000; total time=   1.6s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=1.0, elasticnet__max_iter=1000; total time=   0.8s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=1.0, elasticnet__max_iter=1000; total time=   0.8s
# [CV] END elasticnet__alpha=0.1, elasticnet__l1_ratio=1.0, elasticnet__max_iter=5000; total time=   3.9s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.95, elasticnet__max_iter=5000; total time=   0.1s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.99, elasticnet__max_iter=1000; total time=   0.2s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.99, elasticnet__max_iter=2000; total time=   0.2s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=0.99, elasticnet__max_iter=5000; total time=   0.2s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=1.0, elasticnet__max_iter=1000; total time=   0.9s
# [CV] END elasticnet__alpha=1.0, elasticnet__l1_ratio=1.0, elasticnet__max_iter=5000; total time=   1.0s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.5, elasticnet__max_iter=2000; total time=   0.0s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.5, elasticnet__max_iter=5000; total time=   0.1s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.7, elasticnet__max_iter=1000; total time=   0.0s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.7, elasticnet__max_iter=2000; total time=   0.0s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.7, elasticnet__max_iter=5000; total time=   0.0s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.9, elasticnet__max_iter=2000; total time=   0.1s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.9, elasticnet__max_iter=5000; total time=   0.1s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.95, elasticnet__max_iter=2000; total time=   0.1s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.95, elasticnet__max_iter=2000; total time=   0.1s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.99, elasticnet__max_iter=5000; total time=   0.1s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=0.99, elasticnet__max_iter=5000; total time=   0.1s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=1.0, elasticnet__max_iter=1000; total time=   0.2s
# [CV] END elasticnet__alpha=10.0, elasticnet__l1_ratio=1.0, elasticnet__max_iter=5000; total time=   0.4s

# %%
y_train_pred = elastic_grid_search.best_estimator_.predict(X_train)
rmse_train = mean_squared_error(y_train, y_train_pred)**(1/2)
print(f'RMSE (Train Set): ${rmse_train:.2f}')

rmse_test = mean_squared_error(y_test, y_test_pred)**(1/2)
print(f'RMSE (Test Set): ${rmse_test:.2f}')

# Ignore ConvergenceWarnings to prevent them from being displayed
warnings.filterwarnings("ignore", category=ConvergenceWarning)

# Your code with the Elastic Net model training goes here

# Reset warnings to default if needed
warnings.resetwarnings()
# Out:
# RMSE (Train Set): $25035.27
# RMSE (Test Set): $32004.47

# %%
# Model 3: Gradient Boosting Machine

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
# Define the parameter grid
param_grid = {
    'regressor__n_estimators': [50, 100, 150],
    'regressor__learning_rate': [0.01, 0.1, 0.2],
    'regressor__max_depth': [3, 4, 5],
    'regressor__min_samples_split': [2, 5, 10],
    'regressor__min_samples_leaf': [1, 2, 4]
}

# Create the Gradient Boosting Regressor model
gb_model = GradientBoostingRegressor(random_state=1)

# Create a pipeline with the preprocessor and Gradient Boosting model
gbm_model_pre = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('regressor', gb_model)
])

# Instantiate GridSearchCV with the pipeline and parameter grid
grid_search_model = GridSearchCV(estimator = gbm_model_pre, 
                           param_grid = param_grid, 
                           cv=5, 
                           scoring='neg_mean_squared_error', 
                           n_jobs=-1)

# Fit the grid search to the data
grid_search_model.fit(X_train, y_train)

# Print the best parameters found
print("Best Hyperparameters:", grid_search_model.best_params_)

# Get the best model
best_gbm_model = grid_search_model.best_estimator_
# Out:
# Best Hyperparameters: {'regressor__learning_rate': 0.1, 'regressor__max_depth': 3, 'regressor__min_samples_leaf': 1, 'regressor__min_samples_split': 2, 'regressor__n_estimators': 150}

# %%
# Make predictions on the test set using the best model
y_test_pred_best = best_gbm_model.predict(X_test)

# Evaluate the best model
mse_best = MSE(y_test, y_test_pred_best)
rmse_best = np.sqrt(mse_best)

print(f'Generalization error- RMSE: {rmse_best}')
# Out:
# Generalization error- RMSE: 27090.982863677506
# /Users/meetpatel/opt/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/cast.py:1846: DeprecationWarning: np.find_common_type is deprecated.  Please use `np.result_type` or `np.promote_types`.
# See https://numpy.org/devdocs/release/1.25.0-notes.html and the docs for more information.  (Deprecated NumPy 1.25)
#   return np.find_common_type(types, [])  # type: ignore[arg-type]
# /Users/meetpatel/opt/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/cast.py:1846: DeprecationWarning: np.find_common_type is deprecated.  Please use `np.result_type` or `np.promote_types`.
# See https://numpy.org/devdocs/release/1.25.0-notes.html and the docs for more information.  (Deprecated NumPy 1.25)
#   return np.find_common_type(types, [])  # type: ignore[arg-type]

# %%
# Make predictions on the test set using the best model
y_train_pred_best = best_gbm_model.predict(X_train)

# Evaluate the best model performance on training data
mse_train = MSE(y_train, y_train_pred_best)
rmse_train = np.sqrt(mse_train)

print(f'Error on Training data- RMSE: ${rmse_train:.2f}')


# Evaluate the best model
y_test_pred_best = best_gbm_model.predict(X_test)

mse_test = MSE(y_test, y_test_pred_best)
rmse_test = np.sqrt(mse_test)

print(f'Error on Test data- RMSE: ${rmse_test:.2f}')
# Out:
# Error on Training data- RMSE: $8182.11
# Error on Test data- RMSE: $27090.98
# /Users/meetpatel/opt/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/cast.py:1846: DeprecationWarning: np.find_common_type is deprecated.  Please use `np.result_type` or `np.promote_types`.
# See https://numpy.org/devdocs/release/1.25.0-notes.html and the docs for more information.  (Deprecated NumPy 1.25)
#   return np.find_common_type(types, [])  # type: ignore[arg-type]
# /Users/meetpatel/opt/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/cast.py:1846: DeprecationWarning: np.find_common_type is deprecated.  Please use `np.result_type` or `np.promote_types`.
# See https://numpy.org/devdocs/release/1.25.0-notes.html and the docs for more information.  (Deprecated NumPy 1.25)
#   return np.find_common_type(types, [])  # type: ignore[arg-type]
# /Users/meetpatel/opt/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/cast.py:1846: DeprecationWarning: np.find_common_type is deprecated.  Please use `np.result_type` or `np.promote_types`.
# See https://numpy.org/devdocs/release/1.25.0-notes.html and the docs for more information.  (Deprecated NumPy 1.25)
#   return np.find_common_type(types, [])  # type: ignore[arg-type]
# /Users/meetpatel/opt/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/cast.py:1846: DeprecationWarning: np.find_common_type is deprecated.  Please use `np.result_type` or `np.promote_types`.
# See https://numpy.org/devdocs/release/1.25.0-notes.html and the docs for more information.  (Deprecated NumPy 1.25)
#   return np.find_common_type(types, [])  # type: ignore[arg-type]

# %%
# trying RandomSearch to fine tune GBM's hyper parameters

from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint

# Define the parameter grid for Randomized Search
param_dist = {
    'regressor__n_estimators': randint(50, 200),
    'regressor__learning_rate': [0.01, 0.1, 0.2, 0.5],
    'regressor__max_depth': randint(3, 10),
    'regressor__min_samples_split': randint(2, 20),
    'regressor__min_samples_leaf': randint(1, 10)
}

# Instantiate RandomizedSearchCV
random_search = RandomizedSearchCV(
    estimator=gbm_model_pre,
    param_distributions=param_dist,
    scoring='neg_mean_squared_error',
    n_iter=10,  # Number of parameter settings that are sampled
    cv=5,
    random_state=1,
    n_jobs=-1
)

# Fit the RandomizedSearchCV to the data
random_search.fit(X_train, y_train)

# Print the best parameters found
print("Best Hyperparameters:", random_search.best_params_)

# Get the best model
best_gbm_model_randomsearch = random_search.best_estimator_

# Optionally, you can use the best model for predictions and evaluation
y_test_pred = best_gbm_model_randomsearch.predict(X_test)
# Out:
# /Users/meetpatel/opt/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/cast.py:1846: DeprecationWarning: np.find_common_type is deprecated.  Please use `np.result_type` or `np.promote_types`.
# See https://numpy.org/devdocs/release/1.25.0-notes.html and the docs for more information.  (Deprecated NumPy 1.25)
#   return np.find_common_type(types, [])  # type: ignore[arg-type]
# /Users/meetpatel/opt/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/cast.py:1846: DeprecationWarning: np.find_common_type is deprecated.  Please use `np.result_type` or `np.promote_types`.
# See https://numpy.org/devdocs/release/1.25.0-notes.html and the docs for more information.  (Deprecated NumPy 1.25)
#   return np.find_common_type(types, [])  # type: ignore[arg-type]
# /Users/meetpatel/opt/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/cast.py:1846: DeprecationWarning: np.find_common_type is deprecated.  Please use `np.result_type` or `np.promote_types`.
# See https://numpy.org/devdocs/release/1.25.0-notes.html and the docs for more information.  (Deprecated NumPy 1.25)
#   return np.find_common_type(types, [])  # type: ignore[arg-type]
# /Users/meetpatel/opt/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/cast.py:1846: DeprecationWarning: np.find_common_type is deprecated.  Please use `np.result_type` or `np.promote_types`.
# See https://numpy.org/devdocs/release/1.25.0-notes.html and the docs for more information.  (Deprecated NumPy 1.25)
#   return np.find_common_type(types, [])  # type: ignore[arg-type]
# Best Hyperparameters: {'regressor__learning_rate': 0.1, 'regressor__max_depth': 6, 'regressor__min_samples_leaf': 9, 'regressor__min_samples_split': 11, 'regressor__n_estimators': 183}
# /Users/meetpatel/opt/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/cast.py:1846: DeprecationWarning: np.find_common_type is deprecated.  Please use `np.result_type` or `np.promote_types`.
# See https://numpy.org/devdocs/release/1.25.0-notes.html and the docs for more information.  (Deprecated NumPy 1.25)
#   return np.find_common_type(types, [])  # type: ignore[arg-type]
# /Users/meetpatel/opt/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/cast.py:1846: DeprecationWarning: np.find_common_type is deprecated.  Please use `np.result_type` or `np.promote_types`.
# See https://numpy.org/devdocs/release/1.25.0-notes.html and the docs for more information.  (Deprecated NumPy 1.25)
#   return np.find_common_type(types, [])  # type: ignore[arg-type]

# %%
# Make predictions on the test set using the best model
y_train_pred_best = best_gbm_model_randomsearch.predict(X_train)

# Evaluate the best model performance on training data
mse_train = MSE(y_train, y_train_pred_best)
rmse_train = np.sqrt(mse_train)

print(f'Error on Training data- RMSE: ${rmse_train:.2f}')


# Evaluate the best model
y_test_pred_best = best_gbm_model_randomsearch.predict(X_test)

mse_test = MSE(y_test, y_test_pred_best)
rmse_test = np.sqrt(mse_test)

print(f'Error on Test data- RMSE: ${rmse_test:.2f}')
# Out:
# Error on Training data- RMSE: $5429.32
# Error on Test data- RMSE: $27105.32
# /Users/meetpatel/opt/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/cast.py:1846: DeprecationWarning: np.find_common_type is deprecated.  Please use `np.result_type` or `np.promote_types`.
# See https://numpy.org/devdocs/release/1.25.0-notes.html and the docs for more information.  (Deprecated NumPy 1.25)
#   return np.find_common_type(types, [])  # type: ignore[arg-type]
# /Users/meetpatel/opt/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/cast.py:1846: DeprecationWarning: np.find_common_type is deprecated.  Please use `np.result_type` or `np.promote_types`.
# See https://numpy.org/devdocs/release/1.25.0-notes.html and the docs for more information.  (Deprecated NumPy 1.25)
#   return np.find_common_type(types, [])  # type: ignore[arg-type]
# /Users/meetpatel/opt/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/cast.py:1846: DeprecationWarning: np.find_common_type is deprecated.  Please use `np.result_type` or `np.promote_types`.
# See https://numpy.org/devdocs/release/1.25.0-notes.html and the docs for more information.  (Deprecated NumPy 1.25)
#   return np.find_common_type(types, [])  # type: ignore[arg-type]
# /Users/meetpatel/opt/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/cast.py:1846: DeprecationWarning: np.find_common_type is deprecated.  Please use `np.result_type` or `np.promote_types`.
# See https://numpy.org/devdocs/release/1.25.0-notes.html and the docs for more information.  (Deprecated NumPy 1.25)
#   return np.find_common_type(types, [])  # type: ignore[arg-type]

# %%
# trying Bayesian Optimization for fine-tuning

# %%
# Model 4: Nerual Nets

# %%
# Model 5: Support Vector Machines
